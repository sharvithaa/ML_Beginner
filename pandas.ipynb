# %% [markdown]
# <a href="https://colab.research.google.com/github/sharvithaa/MLpraticeBYTS/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas
#
#
# *   sql is faster than pandas but we use pandas becoz it has more functions and operations.
# *   pyhton is wriiten in c
# pandas back is numpy
# *
# like pandas polars can be used.Polars can be used for big data.
# big data processesing we use Pyspark.
#  Roboflow-Used for data annoatation.
#   robolfow pipeline
#    collect->organize->label->process->train->models->deploy
# * Diff b/w numpy and pandas
#        * In numpy only we cna access using only index where in pandas we can do using index,labels
#        * Numpy can have only one datatype where pandas has multiple datatype.
#    SERIES
#    * 1D array
#    *
#
#
#
#
#
#    DATAFRAME
#    2D array
#
#
#  TPU-Tensor processing unit.Used to process tensor,matirix are tensor.
#  * GPUs excel in parallel processing through several cores or arithmetic logic units (ALU). GPU cores are less powerful than CPU cores and have less memory. While CPUs can switch between different instruction sets rapidly, a GPU simply takes a high volume of the same instructions and pushes them through at high speed.

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([10,20,30,40,50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
s=pd.Series(a)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s[3]
# Out:
# 40

# %%
s.drop(2,inplace=True)
s
# Out:
# 0    10
# 1    20
# 3    40
# 4    50
# dtype: int64

# %%
s.iloc[2]    #using index
# Out:
# 40

# %%
#s.loc[50]    #using element

# %%
s.index
# Out:
# Int64Index([0, 1, 3, 4], dtype='int64')

# %%
a=pd.Series([10,22,23,24,25,26],index=['a','c','c','d','e','f'])
a
# Out:
# a    10
# c    22
# c    23
# d    24
# e    25
# f    26
# dtype: int64

# %%
a['c']
# Out:
# c    22
# c    23
# dtype: int64

# %%
a.loc['c']
# Out:
# c    22
# c    23
# dtype: int64

# %%
#Dataframe
data=[['aaa',10,'23.05.2000'],['bbb',None,None],['cccc',None,'23.5.2003']]
data
# Out:
# [['aaa', 10, '23.05.2000'], ['bbb', None, None], ['cccc', None, '23.5.2003']]

# %%
df=pd.DataFrame(data)
df
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003

# %%
df[0:2]
# Out:
#      0     1           2
# 0  aaa  10.0  23.05.2000
# 1  bbb   NaN        None

# %%
df[0:3]
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003

# %%
df[0][0]
# Out:
# 'aaa'

# %%
df[[0,2]]
# Out:
#       0           2
# 0   aaa  23.05.2000
# 1   bbb        None
# 2  cccc   23.5.2003

# %%
df[0]
# Out:
# 0     aaa
# 1     bbb
# 2    cccc
# Name: 0, dtype: object

# %%
df=pd.DataFrame(data,columns=['Name','Age','DOB'])
df
# Out:
#    Name   Age         DOB
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003

# %%
df['Name'] #case-sensitive
# Out:
# 0     aaa
# 1     bbb
# 2    cccc
# Name: Name, dtype: object

# %%
df['Name'][0]
# Out:
# 'aaa'

# %%
df.loc[0,'Name']
# Out:
# 'aaa'

# %%
df.iloc[0,0]
# Out:
# 'aaa'

# %%
b=pd.Series([10,23,12,45,90])
b
# Out:
# 0    10
# 1    23
# 2    12
# 3    45
# 4    90
# dtype: int64

# %%
b.plot()
# Out:
# <Axes: >

# %%
b.hist(bins=2)
# Out:
# <Axes: >

# %%
c=b.to_numpy()
c
# Out:
# array([10, 23, 12, 45, 90])

# %%
type(c)
# Out:
# numpy.ndarray

# %%
df
# Out:
#    Name   Age         DOB
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003

# %%
df.head(1)
# Out:
#   Name   Age         DOB
# 0  aaa  10.0  23.05.2000

# %%
df.tail(2)
# Out:
#    Name  Age        DOB
# 1   bbb  NaN       None
# 2  cccc  NaN  23.5.2003

# %%
df.tail(-2)
# Out:
#    Name  Age        DOB
# 2  cccc  NaN  23.5.2003

# %%
#None,' ','','-','?','Nil',np.nan(not a number)
df.isnull().sum()
# Out:
# Name    0
# Age     2
# DOB     1
# dtype: int64

# %%
data=[['aaa',10,'23.05.2000'],['bbb',None,None],['cccc',None,'23.5.2003'],['dddd',None,'20.2.1988'],['eee',3,'5.7.2021']]
df=pd.DataFrame(data)
df
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
df.isnull().sum()
# Out:
# 0    0
# 1    3
# 2    1
# dtype: int64

# %%
df.dropna()
# Out:
#      0     1           2
# 0  aaa  10.0  23.05.2000
# 4  eee   3.0    5.7.2021

# %%
df.drop?

# %%
df
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
#df.drop(['Age'],axis=1)
df
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
df.drop([1,2])
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
c
# Out:
# array([10, 23, 12, 45, 90])

# %%
a>40
# Out:
# a    False
# c    False
# c    False
# d    False
# e    False
# f    False
# dtype: bool

# %%
c[c>40]
# Out:
# array([45, 90])

# %%
c[c%2==0]
# Out:
# array([10, 12, 90])

# %%
df
# Out:
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       2 non-null      float64
#  2   2       4 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df[0].str.contains('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: 0, dtype: bool

# %%
df[0].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: 0, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (5, 3)
# 15
# [RangeIndex(start=0, stop=5, step=1), RangeIndex(start=0, stop=3, step=1)]
# 2
# 0     object
# 1    float64
# 2     object
# dtype: object
# RangeIndex(start=0, stop=5, step=1)
# RangeIndex(start=0, stop=3, step=1)
# [['aaa' 10.0 '23.05.2000']
#  ['bbb' nan None]
#  ['cccc' nan '23.5.2003']
#  ['dddd' nan '20.2.1988']
#  ['eee' 3.0 '5.7.2021']]

# %%
df[0]
# Out:
# 0     aaa
# 1     bbb
# 2    cccc
# 3    dddd
# 4     eee
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# 'aaa'

# %%
df[2][1]='20.2.2003'
df
# Out:
# <ipython-input-205-70a88f0ac1c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[2][1]='20.2.2003'
#       0     1           2
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN   20.2.2003
# 2  cccc   NaN   23.5.2003
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
#reading from file  read only table from that page
df=pd.read_html("https://en.wikipedia.org/wiki/Music_of_Tamil_Nadu")
df
# Out:
# [    0                                                  1
#  0 NaN  This article needs additional citations for ve...,
#                                                     0
#  0                                Part of a series on
#  1                                             Tamils
#  2  History History of Tamil Nadu History of Sri L...
#  3  Culture Language Literature Philosophy Script ...
#  4  People Indian Tamils Sri Lankan Tamils Malaysi...
#  5  Tamil diaspora Indian Tamil diaspora Sri Lanka...
#  6  Religion Religion in ancient Tamil country Tam...
#  7  Politics Politics of Tamil Nadu Dravidian nati...
#  8                                       Tamil portal
#  9  .mw-parser-output .navbar{display:inline;font-...]

# %%
# f=pd.read_table("") for tsv

# %%
df=pd.DataFrame(data,columns=['Name','Age','DOB'])
df
# Out:
#    Name   Age         DOB
# 0   aaa  10.0  23.05.2000
# 1   bbb   NaN        None
# 2  cccc   NaN   23.5.2003
# 3  dddd   NaN   20.2.1988
# 4   eee   3.0    5.7.2021

# %%
type(df['Name']) #
# Out:
# pandas.core.series.Series

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price=df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-212-5f86cc00013c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#df.item_price=df.item_price*100
#df

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink=df[df.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %% [markdown]
# df_drink.item_name.nunique()

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 9       [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 31      [[Roasted Chili Corn Salsa (Medium), Fresh Tom...
# 43      [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...
# 46      [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...
#                               ...
# 4546    [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]
# 4607    [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 4610    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# Name: choice_description, Length: 368, dtype: object>

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_name=='Chicken Bowl') &(df.item_price<10)].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
movies=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies[(movies.star_rating>8)&(movies.content_rating=='PG-13')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 232          8.1                                  Chungking Express
# 279          8.1                    The Perks of Being a Wallflower
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# 25           8.6                                  Life Is Beautiful
# 196          8.1                            Guardians of the Galaxy
# 180          8.2                                       Hotel Rwanda
# 73           8.4                            Jodaeiye Nader az Simin
# 260          8.1                                     The Sea Inside
# 118          8.3                 Indiana Jones and the Last Crusade
# ...

# %%
movies[movies.actors_list.str.contains('Tom Hardy')].sort_values(['star_rating','duration'])
# Out:
#      star_rating                  title content_rating   genre  duration  \
# 146          8.2                Warrior          PG-13   Drama       140
# 43           8.5  The Dark Knight Rises          PG-13  Action       165
#
#                                            actors_list
# 146    [u'Tom Hardy', u'Nick Nolte', u'Joel Edgerton']
# 43   [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...

# %%
movies[movies.actors_list.str.contains('Tom Hardy')].sort_values(['duration','star_rating'],ascending=(True,False))
# Out:
#      star_rating                  title content_rating   genre  duration  \
# 146          8.2                Warrior          PG-13   Drama       140
# 43           8.5  The Dark Knight Rises          PG-13  Action       165
#
#                                            actors_list
# 146    [u'Tom Hardy', u'Nick Nolte', u'Joel Edgerton']
# 43   [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
df1
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df1.dropna(subset=['City','Shape Reported'],how='any').shape  #take any one in city or shape reported
# Out:
# (15576, 5)

# %%
df1.dropna(subset=['City','Shape Reported'],how='all').shape  #take two also
# Out:
# (18237, 5)

# %%
df1['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
df2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df2['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
df2['beer_servings'].min()
# Out:
# 0

# %%
df2['beer_servings'].max()
# Out:
# 376

# %%
df2.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df2[df2['continent']=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
df2[df2['continent']=='Asia'].beer_servings.agg(['mean','max','min'])
# Out:
# mean     37.045455
# max     247.000000
# min       0.000000
# Name: beer_servings, dtype: float64

# %%
df2.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
df2.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
